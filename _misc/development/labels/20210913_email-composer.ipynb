# %%
import pickle
import smtplib
from time import sleep
from email.mime.multipart import MIMEMultipart
from email.mime.text import MIMEText
from django.core.mail import send_mail
from django.conf import settings

# %%
from typing import List

class HTML_tag():
    def __init__(self, tag: str, attrs: str, cont: str = None) -> None:
        self.is_singleton = tag in ["img", "br", "hr", "input", "link", "meta"]
        self.__parent = None
        self.__children = None
        self.initialize_tag(tag, attrs, cont)
                
    def initialize_tag(self, tag: str, attrs: str, cont: str) -> None:
        # Checking that singleton tags have no content assigned.
        if self.is_singleton and cont:
            raise Exception(f"Content given to singleton tag: <{tag}>")
        # Initializing 
        else:
            self.tag = tag
            self.attrs = attrs
            self.cont = cont
                
    def compose_attrs(self) -> str:
        return " ".join([f'{i}="{self.attrs[i]}"' for i in self.attrs.keys()])
    
    def compose_tag(self) -> str:
        if self.is_singleton:
            return f'<{self.tag} {self.compose_attrs()}/>'
        else:
            return f'<{self.tag} {self.compose_attrs()}>{self.cont}</{self.tag}>'
    
    def is_circular_dependency(self, ):
        if self.__parent or self.__children:
            return self.__parent in self.__children
    
    def get_parent(self):
        return self.__parent
    
    def set_parent(self, parent: HTML_tag) -> None:
        if parent.is_singleton:
            raise Exception("A singleton cannot be a parent")
        if self.__children:
            if not parent in self.__children:
                self.__parent = parent
            else:
                raise Exception("Circular dependency, a parent cannot be any of children")
        else:
            self.__parent = parent
        
    def get_children(self):
        return self.__children
    
    def set_children(self, children: List[HTML_tag]) -> None:
        if self.is_singleton:
            raise Exception("Singletons cannot have children")
        if self.__parent:
            if not self.__parent in children:
                self.__children = children
            else:
                raise Exception("Circular dependency, a parent cannot be any of children")
        else:
            self.__children = children
    
    def __str__(self) -> str:
        return self.compose_tag()
        
class HTML_snippet():
    def __init__(self, tags: dict) -> None:
        self.tree = tags

# %%
a = HTML_tag("a", {"href":"www.amigasvntg.cl", "target":"_blank"}, "Amigas Vntg")
p = HTML_tag("p", {"style":"font-weigth:400"}, "Lorem ipsum dolor sit amet...")
h1 = HTML_tag("h1", {"style":"font-weigth:400"}, "Lorem ipsum dolor sit amet...")
img = HTML_tag("img", {"url":"www.github.com/AVC/AVC001/1.png", "alt":"lorem ipsum dolor"})

# %%
print(a)
print(p)
print(h1)
print(img)
# Out:
# <a href="www.amigasvntg.cl" target="_blank">Amigas Vntg</a>
# <p style="font-weigth:400">Lorem ipsum dolor sit amet...</p>
# <h1 style="font-weigth:400">Lorem ipsum dolor sit amet...</h1>
# <img url="www.github.com/AVC/AVC001/1.png" alt="lorem ipsum dolor"/>

# %%
a.set_parent(h1)
a.set_children([img])
print(a.get_parent(), [f"{i}" for i in a.get_children()], a, sep="\n")
# Out:
# <h1 style="font-weigth:400">Lorem ipsum dolor sit amet...</h1>
# ['<img url="www.github.com/AVC/AVC001/1.png" alt="lorem ipsum dolor"/>']
# <a href="www.amigasvntg.cl" target="_blank">Amigas Vntg</a>

# %%
b = HTML_snippet([a, img])

# %%
print(b)
# Out:
# <__main__.HTML_snippet object at 0x7fc275322be0>

# %%
with open("./20210909_old-clients-emails.pkl", "rb") as f:
    CLIENT_EMAILS = pickle.load(f)

# %%
USER = "amigas.vntg@gmail.com"
PASSWORD = "Helga1Simona"
GMAIL_KEY = "rljapezpielehdzt"

# %%
FROM = "amigas.vntg@gmail.com"
TO = "amigas.vntg@gmail.com"
SUBJECT = "Panorama vintage este viernes! 😏🔥"
BODY = f"""
<!DOCTYPE html>
<html lang="es" xmlns="http://www.w3.org/1999/xhtml" xmlns:o="urn:schemas-microsoft-com:office:office">
<head>
    <meta http-equiv="Content-Type" content="text/html; charset=UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <meta name="x-apple-disable-message-reformatting">
    <!--[if !mso]><!--><meta http-equiv="X-UA-Compatible" content="IE=edge"><!--<![endif]-->
    <title></title>
    <!--[if mso]>
    <noscript>
        <xml>
            <o:OfficeDocumentSettings>
                <o:PixelsPerInch>96</o:PixelsPerInch>
            </o:OfficeDocumentSettings>
        </xml>
    </noscript>
    <![endif]-->
</head>
<!--<body style="background-color:#f3f3f9;padding:40px;box-sizing:border-box;">-->
<body style="margin:0;padding:0;word-spacing:normal;background-color:#f3f3f6;">
    <div role="article" aria-roledescription="email" lang="en" style="text-size-adjust:100%;-webkit-text-size-adjust:100%;-ms-text-size-adjust:100%;background-color:#f3f3f6;">
        <table role="presentation" style="width:100%;border:none;border-spacing:0;">
            <tr>
                <td align="center" style="padding:0;">
                    <!--[if mso]>
                    <table role="presentation" align="center" style="width:600px;">
                    <tr>
                    <td>
                    <![endif]-->
                        <table role="presentation" style="width:94%;max-width:600px;border:none;border-spacing:0;text-align:left;font-family:'Roboto',Arial,sans-serif;font-size:16px;line-height:22px;color:#363636;margin:auto;">
                            <tr>
                                <td style="padding:50px 0 30px 0;text-align:center;background-color:#f3f3f6" colspan="3">
                                    <a href="https://www.amigasvntg.cl/" style="text-decoration:none;">
                                        <img src="https://raw.githubusercontent.com/RamonOpazo/AmigasVntg_Catalog/master/_misc/logo/png/AmigasVntg_800px.png" width="120" alt="Logo" style="width:80%;max-width:120px;height:auto;border:none;text-decoration:none;color:#ffffff;">
                                    </a>
                                </td>
                            </tr>
                            <tr>
                                <td style="padding:30px;background-color:#ffffff;" colspan="3">
                                    <h1 style="margin-top:0;margin-bottom:16px;font-size:26px;line-height:32px;font-weight:bold;letter-spacing:-0.02em;">Hola#CLIENTNAME#!</h1>
                                    <p style="margin:0;">
                                        <span>Te invitamos este viernes a nuestro primer evento <strong>After Office</strong>! 🥂</span>
                                        <span style="display:block;">Te esperamos con descuentos, espumante y el mejor vintage! 😊</span>
                                    </p>
                                </td>
                            </tr>
                            <tr>
                                <td colspan="3">
                                    <a href="https://www.instagram.com/p/CTlQRKSnYk_/" style="display:block;margin:0;padding:0;line-height:0;">
                                        <img src="https://raw.githubusercontent.com/RamonOpazo/AmigasVntg_Catalog/master/_misc/newsletter/20210909_invitation-after-office_600px.png" style="max-width: 600px;">
                                    </a>
                                </td>
                            </tr>
                            <tr>
                                <td colspan="3">
                                    <div style="display:block; height: 3em; background-color: white;"/>
                                </td>
                            </tr>
                            <tr>
                                <td colspan="3">
                                    <a href="https://goo.gl/maps/TP2sCLdTWGZ4BTWh8" style="display:block;margin:0;padding:0;line-height:0;">
                                        <img src="https://raw.githubusercontent.com/RamonOpazo/AmigasVntg_Catalog/master/_misc/newsletter/20210909_location-showroom_600px.png" style="max-width: 600px;">
                                    </a>
                                </td>
                            </tr>
                            <tr>
                                <td colspan="3">
                                    <div style="display:block; height: 3em; background-color: white;"/>
                                </td>
                            </tr>
                            <tr style="font-size:0.8em;vertical-align:top;background-color:rgb(187,232,213,1);color: #333333;">
                                <td style="padding:30px;padding-right:0;width:33.33%;">
                                    <p style="text-transform:uppercase;color:#4b4b4b;">Tienda</p>
                                    <ul style="list-style:none;padding:0;">
                                        <li style="margin:0;"><a style="color:inherit;" href="https://www.amigasvntg.cl/" title="Inicio">Inicio</a></li>
                                        <li style="margin:0;"><a style="color:inherit;" href="https://www.amigasvntg.cl/productos" title="Productos">Productos</a></li>
                                        <li style="margin:0;"><a style="color:inherit;" href="https://www.amigasvntg.cl/colecciones" title="Colecciones">Colecciones</a></li>
                                    </ul>
                                </td>
                                <td style="padding:30px;padding-right:0;width:33.33%;">
                                    <p style="text-transform:uppercase;color:#4b4b4b;">Información</p>
                                    <ul style="list-style:none;padding:0;">
                                        <li style="margin:0;"><a style="color:inherit;" href="https://www.amigasvntg.cl/about" title="About">About</a></li>
                                        <li style="margin:0;"><a style="color:inherit;" href="https://www.amigasvntg.cl/politica-de-servicio" title="Política de servicio">Política de servicio</a></li>
                                        <li style="margin:0;"><a style="color:inherit;" href="https://www.amigasvntg.cl/politica-de-privacidad" title="Política de privacidad">Política de privacidad</a></li>
                                        <li style="margin:0;"><a style="color:inherit;" href="https://www.amigasvntg.cl/preguntas-frecuentes" title="Preguntas frecuentes">Preguntas frecuentes</a></li>
                                        <li style="margin:0;"><a style="color:inherit;" href="https://www.amigasvntg.cl/guia-de-tallas" title="Guía de tallas">Guía de tallas</a></li>                                        
                                        <li style="margin:0;"><a style="color:inherit;" href="https://www.amigasvntg.cl/contact" title="Contacto">Contacto</a></li>
                                    </ul>
                                </td>
                                <td style="padding:30px;padding-leeft:0;width:33.33%;">
                                    <p style="text-transform:uppercase;color:#4b4b4b;">Síguenos</p>
                                    <ul style="list-style:none;padding:0;">
                                        <li style="margin:0;"><a style="color:inherit;" href="https://www.instagram.com/amigas.vntg" title="Ir a Instagram" target="_blank">Instagram</a></li>
                                    </ul>
                                </td>
                            </tr>
                            <tr style="font-size:0.8em;vertical-align:top;background-color:rgb(187,232,213,1);color: #333333;">
                                <td style="padding:0;text-align:center;" colspan="3">
                                    <hr style="border:none;border-top:1px solid rgba(0,0,0,.1);">
                                </td>
                            </tr>
                            <tr style="font-size:0.8em;vertical-align:top;background-color:rgb(187,232,213,1);color: #333333;">
                                <td style="padding:30px;text-align:center;" colspan="3">
                                    <p>2021 Amigas Vntg &reg; Todos los derechos reservados.</p>
                                </td>
                            </tr>
                            <tr>
                                <td style="padding-top:50px;" colspan="3"></td>
                            </tr>
                        </table>
                    <!--[if mso]>
                    </td>
                    </tr>
                    </table>
                    <![endif]-->
                </td>
            </tr>
        </table> 
    </div>
</body>
</html>
"""

# %%
def mount_server(_user, _password):
    try:
        server = smtplib.SMTP_SSL('smtp.gmail.com', 465)
        server.ehlo()
        server.login(_user, _password)
        print('\tSuccesful connection to server...')
        return server
    except Exception as err:
        print('\tSomething went wrong...')
        print(f'\t{err}')

# %%
def create_message(_from, _to, _subject, _body):
    msg = MIMEMultipart()
    msg['From']=_from
    msg['To']=_to
    msg['Subject']=_subject
    msg.attach(MIMEText(_body, 'html'))
    return msg

# %%
def send_email(client, email):
    print(f"Sending email to «{client}» - {email}")
    if client[0] == "_":
        client_name = ""
    else:
        client_name = f" {client.strip().split()[0]}"
    try:
        server = mount_server(USER, GMAIL_KEY)
        server.send_message(create_message(FROM, email, SUBJECT, BODY.replace("#CLIENTNAME#", f"{client_name}")))
        print("\tEmail sent!")
    except Exception as err:
        print(f'\tFailure to deliver email to recipient «{client}». Trying again in five seconds...')
        sleep(5)
        send_email(client, email)

# %%
CLIENT_EMAILS["COPY:AMIGASVNTG"] = "amigas.vntg@gmail.com"
CLIENT_EMAILS["COPY:COTÉ"] = "mescarates@gmail.com"
CLIENT_EMAILS["COPY:RAMÓN"] = "ramon.opazo.c@gmail.com"

for client, email in CLIENT_EMAILS.items():
    send_email(client, email)
# Out:
# Sending email to «Adriana Latorre Carvallo» - candidadoyle79@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Akza Ugarte» - akzaugartell@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Alejandra Aparicio» - aparicio.diaz.a@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Alejandra Campos» - alejandra.campos.lefno@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Alejandra Espinoza García» - aleliespi@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Alejandra Ortega» - alejandrapatriciaog@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Alejandra Oyarzún Vargas» - alejandra.oyarzun@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Alejandra Rojas Calderón» - vintalogic@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Alejandra Valeria González Guevara» - alealdea@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Alexandra Fajardo Razmilic» - afajardoraz@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Amparo Gutiérrez» - amparo.gutierrez@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Ana Fernandez» - viinushkaf@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Ana Yañez» - anayanez@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Andrea Araneda» - anunica@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Andrea Echeverría» - andrea.echeverriaa@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Andrea Manríquez» - andrea.manriquez.b@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Andrea Salazar» - andri_192@hotmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Andrea San Martín» - andreasmv@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Andrea Silva» - an.sil.moz@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Angélica Villalobos» - angelicavillalobosviveros@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Anna Karina Morales» - akarimm@hotmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Antonieta Lanas Canales» - alanasc@ug.uchile.cl
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Ariana Henriquez» - arianita.hen@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Barbara Carreño» - barbaracarrenopozo@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Belén Figueroa» - blnfigueroa@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Bernardita » - bernardita.bric@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Brenda Casanga Astorga» - brenda16eduardo@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Brenda Rain» - brain@fen.uchile.cl
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Bárbara Poblete» - barbara_ale_12@hotmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Caitlin Mcnamara» - cait.mcn9@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Camila Alonso» - camilaalonso.desogn@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Camila Banchero» - bancherotj@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Camila Cabello» - crcabell@uc.cl
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Camila Carreño» - camicarreno@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Camila Durán» - camiduranmella@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Camila Espinoza Sylvester» - alimacespinoza@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Camila Francisca Rebolledo González» - cami_franc@hotmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Camila Herrera» - camila.herrerarojas93@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Camila Lobos» - kamila.antonia92@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Camila Lobos Harper» - kamila.antonia92@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Camila Lorca» - camisinger@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Camila Mayanz» - camila.mayanz@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Camila Rebolledo» - camilarebolledovidal@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Camila Reyes Retamal» - cami.reyes.retamal@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Camila Rojas Riquelme» - camihilator@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Camila Solis» - camisolis@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Carla Cortes» - carla.cortes.pp@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Carla Ferrada» - carla.ferrada.r@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Carla Peña» - cpenag@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Carmen Paz Inostroza Burgos» - carmenpazib@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Carmen Suárez» - carmenspardo@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Carolina Ahumada Ortiz» - cc.ahumada@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Carolina Carrasco» - karitocarrascoc@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Carolina Nahuelpi» - carolinanahuelpia@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Carolina Nuñez» - dranunezbsb@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Carolina Rodriguez Vergara» - carolina.rodriguez.v@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Catalina Alejandra Serey Valdivia» - catalina.sereyv@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Catalina Alvarado» - cm.alvarado.alarcon@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Catalina Avendaño» - catalina.avenda02@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Catalina Espinoza Gallardo» - catalina.esga@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Catalina Romo» - cata.romoe@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Catalina Romo Escudero» - cata.romoe@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Catalina Villanueva» - cavillanuevas@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Catalina Álvarez» - cataalvarezhalal@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Cecilia Amigo Hermosilla» - cecilia.amigo@yahoo.es
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Chandra Kripalani» - chandrakripalani@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Cinthia Garrido» - garridovalenciac@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Cinthia Paz» - cinthia.diaz@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Cinthia Zamora» - cinthia_adm90@yahoo.cl
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Claudia Breton Jara» - claudiabretonjara@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Claudia Herreros» - pitoness@hotmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Claudia Montero» - cafenparis@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Claudia Pons García» - claudia.pons.garcia@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Claudia Rodríguez» - clrodrig@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Constanza Barraza» - constanza.barrazaj@gmail.com
# 	Something went wrong...
# Connection unexpectedly closed
# 	Failure to deliver email to recipient «Constanza Barraza». Trying again in five seconds...
# Sending email to «Constanza Barraza» - constanza.barrazaj@gmail.com
# 	Something went wrong...
# Connection unexpectedly closed
# 	Failure to deliver email to recipient «Constanza Barraza». Trying again in five seconds...
# Sending email to «Constanza Barraza» - constanza.barrazaj@gmail.com
# 	Something went wrong...
# Connection unexpectedly closed
# 	Failure to deliver email to recipient «Constanza Barraza». Trying again in five seconds...
# Sending email to «Constanza Barraza» - constanza.barrazaj@gmail.com
# 	Something went wrong...
# Connection unexpectedly closed
# 	Failure to deliver email to recipient «Constanza Barraza». Trying again in five seconds...
# Sending email to «Constanza Barraza» - constanza.barrazaj@gmail.com
# 	Something went wrong...
# Connection unexpectedly closed
# 	Failure to deliver email to recipient «Constanza Barraza». Trying again in five seconds...
# Sending email to «Constanza Barraza» - constanza.barrazaj@gmail.com
# 	Something went wrong...
# Connection unexpectedly closed
# 	Failure to deliver email to recipient «Constanza Barraza». Trying again in five seconds...
# Sending email to «Constanza Barraza» - constanza.barrazaj@gmail.com
# 	Something went wrong...
# Connection unexpectedly closed
# 	Failure to deliver email to recipient «Constanza Barraza». Trying again in five seconds...
# Sending email to «Constanza Barraza» - constanza.barrazaj@gmail.com
# 	Something went wrong...
# Connection unexpectedly closed
# 	Failure to deliver email to recipient «Constanza Barraza». Trying again in five seconds...
# Sending email to «Constanza Barraza» - constanza.barrazaj@gmail.com
# 	Something went wrong...
# Connection unexpectedly closed
# 	Failure to deliver email to recipient «Constanza Barraza». Trying again in five seconds...
# Sending email to «Constanza Barraza» - constanza.barrazaj@gmail.com
# 	Something went wrong...
# Connection unexpectedly closed
# 	Failure to deliver email to recipient «Constanza Barraza». Trying again in five seconds...
# Sending email to «Constanza Barraza» - constanza.barrazaj@gmail.com
# 	Something went wrong...
# Connection unexpectedly closed
# 	Failure to deliver email to recipient «Constanza Barraza». Trying again in five seconds...
# Sending email to «Constanza Barraza» - constanza.barrazaj@gmail.com
# 	Something went wrong...
# Connection unexpectedly closed
# 	Failure to deliver email to recipient «Constanza Barraza». Trying again in five seconds...
# Sending email to «Constanza Barraza» - constanza.barrazaj@gmail.com
# 	Something went wrong...
# Connection unexpectedly closed
# 	Failure to deliver email to recipient «Constanza Barraza». Trying again in five seconds...
# Sending email to «Constanza Barraza» - constanza.barrazaj@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Constanza De Larderel» - constanzadelarderel@yahoo.com.ar
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Constanza Florestano» - coni.flo@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Constanza Olivo» - murkia@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Constanza Suárez» - csuarez@emlenguaje.ucsc.cl
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Constanza Villalobos» - co.villalobosponce@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Cristina Gaete Pavez» - cristina.gaetep@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Cristina López Romero» - cristina.lopez.romero87@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Cristina Vera» - cristinaverab@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Daniela Anuel Tousaint» - danielaanuel8491@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Daniela Eujenín Cárdenas» - danielaeujenin@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Daniela Leiva Figueroa» - danielaleiva21@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Daniela Plaza» - daniplazasalgado@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Daniela Valderas Vargas» - dvalderasv@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Daniela Velez» - danielavelezs@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Daniela Zúñiga Villagran» - dc.zunigavillagran@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Daysi Huerta» - daysi_dd@hotmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Diana Claro» - dianaclaro01@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Dino» - mbcabell@uc.cl
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Dominique Dufflocq» - dufflocq.w@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Domynike Galarce González» - dgalarcegonzalez@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Débora Lecaros» - debora.lecaros@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Elena Zapata» - elenapazzapatab@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Eliana Sánchez» - elianaluz.sanchezm@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Elisabet Aylwin Pincheira» - elisabetaylwin@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Emma Marín» - emma@sadhanayoga.cl
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Esperanza Oyarzún» - esperanza.oyarzun@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Estephanie Muñoz» - estephaniemunoz@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Fabiola Gálvez» - fabiolagalvez@hotmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Florencia Carrasco» - florenciaabello@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Florencia Macchi» - flomacchi@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Florencia Moyano» - florenciamoyanom@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Florencia Pinto Troncoso» - fcpinto@uc.cl
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Francesca Alfaro Olavarría» - profe.francesca.alfaro@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Francia Varas» - francia.angeliec.95@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Francis Navarro Canales» - fnavarrocanales@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Francisca Bulnes» - fran.bulnes@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Francisca Flores» - francisca.fpesse@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Francisca Mateluna» - mf.mateluna@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Francisca Millacura Bravo» - franmillacura2013@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Francisca Rojas Pizarro» - francisca.rojaspizarro@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Gabriela Lobos» - gabolobosk@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Gabriela Piña» - gapina@uc.cl
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Gabriela Soria» - gabysoria.rios.199@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Geraldine Morillo» - sevienda@hotmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Gianinnaferrari» - gianinnaferrari@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Gina Miranda» - gmirandasaez@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Ingrid Silva Agüero» - ingrids8@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Isabel Araos» - isabelaraos@hotmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Isabel Ross» - isabel.ross.k@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Isabel Rubilar» - rubilar.isabel@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Isadora Schmidt» - schmidt.isadora@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Isidora Javalquinto» - isidora.javalquinto@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Ivana Bachmann» - ivana.bachmann@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Jael Parra Medina» - jaelparramedina@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Javiera Avilés Torres» - javiera.aviles@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Javiera Badilla» - javiera.badilla.a@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Javiera Godoy» - javierapazgodoyz@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Javiera Gálvez Riveros» - javiera.galvezr@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Javiera Vásquez» - jzvasque@uc.cl
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Jeannette Pendola Arriagada» - jpendolaa@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Jenny Carmona» - jenny.carmona@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Jessica Candia» - jcandiachocano@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Jorge Salgado Prieto» - yeisacruces@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Juana Monsalve Castillo» - monsalve.juany@hotmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Kamila Urbina» - kamila.urbina@usach.cl
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Karina Bugueño Campos» - kbugueno01@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Karina Torres» - karina.torres.bastias@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Karina Yevenes» - kp.yevenes@gmail.gom
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Karla Patricia Ramírez» - karlapatricia.ram@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Karla Ramírez» - karlapatricia.ram@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Katherinne Añasco Avila» - katherinne_anasco@hotmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Kattia Fonseca Pacheco» - kattia.fonpa1983@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Krito Segovia» - krito.segovia@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Küyen Mansilla» - km.quilaqueo@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Larissa Rojas Marilao» - eu.larissarojas@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Laura Sepúlveda» - laura.sepulveda@mercurio.cl
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Lorena Gonzalez» - lgtaborga@gmail.com
# 	Something went wrong...
# Connection unexpectedly closed
# 	Failure to deliver email to recipient «Lorena Gonzalez». Trying again in five seconds...
# Sending email to «Lorena Gonzalez» - lgtaborga@gmail.com
# 	Something went wrong...
# Connection unexpectedly closed
# 	Failure to deliver email to recipient «Lorena Gonzalez». Trying again in five seconds...
# Sending email to «Lorena Gonzalez» - lgtaborga@gmail.com
# 	Something went wrong...
# Connection unexpectedly closed
# 	Failure to deliver email to recipient «Lorena Gonzalez». Trying again in five seconds...
# Sending email to «Lorena Gonzalez» - lgtaborga@gmail.com
# 	Something went wrong...
# Connection unexpectedly closed
# 	Failure to deliver email to recipient «Lorena Gonzalez». Trying again in five seconds...
# Sending email to «Lorena Gonzalez» - lgtaborga@gmail.com
# 	Something went wrong...
# Connection unexpectedly closed
# 	Failure to deliver email to recipient «Lorena Gonzalez». Trying again in five seconds...
# Sending email to «Lorena Gonzalez» - lgtaborga@gmail.com
# 	Something went wrong...
# Connection unexpectedly closed
# 	Failure to deliver email to recipient «Lorena Gonzalez». Trying again in five seconds...
# Sending email to «Lorena Gonzalez» - lgtaborga@gmail.com
# 	Something went wrong...
# Connection unexpectedly closed
# 	Failure to deliver email to recipient «Lorena Gonzalez». Trying again in five seconds...
# Sending email to «Lorena Gonzalez» - lgtaborga@gmail.com
# 	Something went wrong...
# Connection unexpectedly closed
# 	Failure to deliver email to recipient «Lorena Gonzalez». Trying again in five seconds...
# Sending email to «Lorena Gonzalez» - lgtaborga@gmail.com
# 	Something went wrong...
# Connection unexpectedly closed
# 	Failure to deliver email to recipient «Lorena Gonzalez». Trying again in five seconds...
# Sending email to «Lorena Gonzalez» - lgtaborga@gmail.com
# 	Something went wrong...
# Connection unexpectedly closed
# 	Failure to deliver email to recipient «Lorena Gonzalez». Trying again in five seconds...
# Sending email to «Lorena Gonzalez» - lgtaborga@gmail.com
# 	Something went wrong...
# Connection unexpectedly closed
# 	Failure to deliver email to recipient «Lorena Gonzalez». Trying again in five seconds...
# Sending email to «Lorena Gonzalez» - lgtaborga@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Lorena Ortiz» - lore.of@hotmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Lorena Vargas» - lorenaconstanza.vr@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Loreto Marttell» - loretomarttell@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Loretta Ugalde» - loretta.ugalde.rodriguez@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Macarena Jofre» - macajofre87@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Macarena Macaya Arancibia» - mmacaya1@uc.cl
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Macarena Torres» - macatorresm@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Magdalena Rivas» - maidarivas@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Marcela Llancafil» - m.llancafil.m@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Marcela Quintas» - marcela.quintas.i@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Margarita Ulloa Quezada» - marga.ulloa.q@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Maria Avila» - m.coniavila.d@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Maria Constanza Toledo» - mconstanzat@hotmail.cl
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Maria Eugenia Ruiz» - kenina86@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Maria Fernanda Collao Brantt» - fernandacollao@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Maria Ignacia Soto» - uribe.ina@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Maria Inés Henseleit» - ines_henseleit@hotmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Maria Loreto Aravena Riveros» - ml.aravenariveros@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Maria Paz  Merino Pga» - mariapz.merino@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Maria Ramos » - soledad1803@hotmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Maria Torres» - mjtorresc1@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Mariela Gutierrez Ruiz» - marielagutierrezruiz@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Marisol Carvallo» - marisol.carvalloy@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Marlen Urrutia» - marlen.urrutiar@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «María Alejandra Romero» - aleromerosanhueza@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «María Alejandra Troncoso Fuentes » - atroncosofuentes@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «María Ester Ortiz» - mariaesterortiz@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «María Graciela Henriquez» - mghenriquezs@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «María Jesús Pacheco Parada» - mariajesuspacheco.med@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «María José Azócar» - mazocarv@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «María José Croquevielle» - mariajose.croquevielle@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «María Lissette Martínez Pavez» - lisetemartinez@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «María Soledad Ramos» - soledad1803@hotmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Michelle Tapia» - michelle_tapia.calfunao@hotmail.es
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Millicent Otarola Fernandez» - millicent.otarola@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Mitzi González» - mitzi@wados.cl
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Monica Inostroza» - m.inostrozaburgos@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Natalia Albornoz» - satiata@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Natalia Arancibia» - natalia.arancibia@ug.uchile.cl
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Natalia Bustamante» - nbustaguila@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Natalia Espoz» - nespoz.m@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Natalia Lucero» - natalialuceroarte@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Natalia Silva» - nata.silvag@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Natalia Silva Muñoz» - nsilvamunoz@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Natalia Uribe» - natalia.uribe.c@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Nicole Gamonal» - nicole.estefania@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Nicole Palominos» - nicole.palominos@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Nicole Salinas Romero» - nicole.salinasr@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Nicole Sharkey» - nicole.sharkey.s@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Nicolle Benavente» - nbascui@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Nilse Ramírez» - nilseramirezr@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Norma Berrios» - normaberriosg@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Náyade Vargas» - nayadev@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Octavio Aldea sabioncello» - evelynlipka@hotmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Pamela Alarcón Toloza» - pamalarcontoloza@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Pamela Mechsner» - pame.mechsner@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Pamela Riquelme» - priquelmei@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Patricia Pérez» - patricia.perezg@mail.udp.cl
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Paula Amestica Bravo» - bravoamestica@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Paula Aravena» - aravenar.pau@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Paula Nuño» - paula.nuno.b@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Paula Sánchez» - pasanchezsaez@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Paula Urrutia» - pauurrutiadufeu@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Paula Vallejos» - pvallejosla@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Paulina Cortés Ugalde» - paulina.cortes.ugalde@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Paulina Escobar» - paulinaescobarlopez@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Paulina Rivera» - paurs3@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Paz Ayala» - paz.ayala@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Paz Tabilo» - paztabilo@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Pia Servela» - servela.mcr@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Pilar M. Fernández-Komlos» - pfernandezk@yahoo.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Pilar Troncoso» - pilar.troncoso.campos@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Pilar Zuñiga» - pilar.zuniga.h@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Priscilla Flores Reyes» - pri.flores.reyes@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Pía Romero» - piaromero8888@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Roció Rodríguez Sanoja» - rociorodriguezsanoja@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Rocío Merino» - rocio.merino1990@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Romina Fernández» - romina.sfh@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Romina Gallardo» - rominagallardogonzalez@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Romina Martinez» - romina.martinez.m@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Romina Marttell» - romina.marpi@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Romina Martínez» - romina.martinez.m@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Rosa Caco» - rosacaco@hotmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Rosa Espinoza» - rositaelena1610@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Roxana Arauco R» - rookyta@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Roxana Núñez» - roxananunezbecerra@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Ruth Guzman Leiva» - ruthmariange@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Sandra Irarrazabal» - irarrazabalsandra82@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Sandra Sepulveda» - sandrasepulveda.venegas@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Sara Sánchez» - sari.bauza@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Sarame Sepúlveda Martinez» - sarame.sepulveda.martinez@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Silvana Orrego» - silvana.orrego@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Soledad Rivas» - soledad.rivasg@gmail.com
# 	Something went wrong...
# Connection unexpectedly closed
# 	Failure to deliver email to recipient «Soledad Rivas». Trying again in five seconds...
# Sending email to «Soledad Rivas» - soledad.rivasg@gmail.com
# 	Something went wrong...
# Connection unexpectedly closed
# 	Failure to deliver email to recipient «Soledad Rivas». Trying again in five seconds...
# Sending email to «Soledad Rivas» - soledad.rivasg@gmail.com
# 	Something went wrong...
# Connection unexpectedly closed
# 	Failure to deliver email to recipient «Soledad Rivas». Trying again in five seconds...
# Sending email to «Soledad Rivas» - soledad.rivasg@gmail.com
# 	Something went wrong...
# Connection unexpectedly closed
# 	Failure to deliver email to recipient «Soledad Rivas». Trying again in five seconds...
# Sending email to «Soledad Rivas» - soledad.rivasg@gmail.com
# 	Something went wrong...
# Connection unexpectedly closed
# 	Failure to deliver email to recipient «Soledad Rivas». Trying again in five seconds...
# Sending email to «Soledad Rivas» - soledad.rivasg@gmail.com
# 	Something went wrong...
# Connection unexpectedly closed
# 	Failure to deliver email to recipient «Soledad Rivas». Trying again in five seconds...
# Sending email to «Soledad Rivas» - soledad.rivasg@gmail.com
# 	Something went wrong...
# Connection unexpectedly closed
# 	Failure to deliver email to recipient «Soledad Rivas». Trying again in five seconds...
# Sending email to «Soledad Rivas» - soledad.rivasg@gmail.com
# 	Something went wrong...
# Connection unexpectedly closed
# 	Failure to deliver email to recipient «Soledad Rivas». Trying again in five seconds...
# Sending email to «Soledad Rivas» - soledad.rivasg@gmail.com
# 	Something went wrong...
# Connection unexpectedly closed
# 	Failure to deliver email to recipient «Soledad Rivas». Trying again in five seconds...
# Sending email to «Soledad Rivas» - soledad.rivasg@gmail.com
# 	Something went wrong...
# Connection unexpectedly closed
# 	Failure to deliver email to recipient «Soledad Rivas». Trying again in five seconds...
# Sending email to «Soledad Rivas» - soledad.rivasg@gmail.com
# 	Something went wrong...
# Connection unexpectedly closed
# 	Failure to deliver email to recipient «Soledad Rivas». Trying again in five seconds...
# Sending email to «Soledad Rivas» - soledad.rivasg@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Tamara Hidalgo» - tabehico@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Tamara Nazal» - tamy.nazal@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Tamara Venegas» - tavenega@uc.cl
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Tania Rojas» - tania.rp12@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Trinidad Venegas» - cecilia.ramirez.lira@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Valentina Catalán Becerra» - catalanvb@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Valentina Codocedo» - codocedo.vale@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Valentina Díaz» - vale123db@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Valentina Godoy» - valegodoym@hotmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Valentina Paredes Quinteros» - valepq@hotmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Valeria Fernandez Delgado» - valeriafernandez_2000_17@hotmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Valeria Riquelme Estrada» - valeriaesstrada@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Valeska Diaz» - vale5410@hotmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Vanesa Cartes» - cartesmoya205@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Vanessa Arias» - vane_chini_@hotmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Verónica Retamal» - vnfernanda34@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Victoria Escobar Inostroza» - victoria.escobar.inos@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Victoria Silva» - vsilvamack@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Viviana Araya» - vivianaaraya01@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Ximena Venegas Barrientos» - xvenegasb@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Yazmin Díaz Román» - yazmindiazroman@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Yesenia Castillo Pincheira» - yeseniacastillopincheira@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Yessenia Tapia» - yesseniatapia@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «Yina Zúñiga» - yina.zuniga@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «_1» - akarimm@hotmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «_10» - xtombolini@yahoo.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «_2» - cegutierrez@udec.cl
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «_3» - e_myryam@hotmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «_4» - flanxd@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «_5» - huertaencasa.cl@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «_6» - ncaballero51@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «_7» - nheresi@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «_8» - patriciaandreamunoz@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «_9» - vntg@javiertinc.cl
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «COPY:AMIGASVNTG» - amigas.vntg@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «COPY:COTÉ» - mescarates@gmail.com
# 	Succesful connection to server...
# 	Email sent!
# Sending email to «COPY:RAMÓN» - ramon.opazo.c@gmail.com
# 	Succesful connection to server...
# 	Email sent!
